# %%
# %load_ext autoreload
# %autoreload 2

# %%
from hexagon_utilities import *
from colors import *
from plot_functions import *

import matplotlib.pyplot as plt

# %%
fig, ax = plt.subplots(figsize=(20,20))

#bg_color = np.random.choice(YELLOWS_HIGH_SAT)
#bg_color = 'white'
#fc_bg = bg_color
#fig.patch.set_facecolor(fc_bg)

size=10
num_rows, num_cols = 20, 14
hg = HexGrid(num_rows, num_cols, size, flat=True)


fam, col = 0, 0
for idx, h in enumerate(hg.hlist):     
    h.render(fc='none', color='m')

ax.set_aspect('equal')
xclip = 1.2
yclip = 2
x_range=h.w * num_cols/2 * xclip
y_range= h.h/2 * num_rows/2 * yclip   
ax.set_xbound(lower=-1*x_range, upper=x_range)
ax.set_ybound(lower=-1*y_range, upper=y_range)
#ax.set_xlim(left=-30, right=30)
#ax.axis('scaled')    
print(h.h, y_range, h.w, x_range)
# Out:
# 17.32050807568877 173.2050807568877 20 168.0

# %%
fig, ax = plt.subplots()
#h.render(fc=None)
h.render_border(fc='none', color='b')
plt.axis('scaled')
plt.axis('equal')
# Out:
# (244.0, 266.0, 68.41600689897065, 87.46856578222831)

# %%
fig_pixels =  fig.get_size_inches()*fig.dpi # size in pixels

# %%
fig.get_size_inches(), fig.dpi
# Out:
# (array([20., 20.]), 72.0)

# %%
ax.get_data_ratio()
# Out:
# 0.6959132708982095

# %%
x_limits, y_limits = ax.get_xlim(), ax.get_ylim()

# %%
x_limits
# Out:
# (-112.0, 112.0)

# %%
x_range = abs(x_limits[1] - x_limits[0])
x_middle = np.mean(x_limits)
y_range = abs(y_limits[1] - y_limits[0])
y_middle = np.mean(y_limits)

# %%
import matplotlib.pyplot as plt
import numpy as np

# Plot circle of radius 3.

an = np.linspace(0, 2 * np.pi, 100)
fig, axs = plt.subplots(3, 2)

axs[0, 0].plot(3 * np.cos(an), 3 * np.sin(an))
axs[0, 0].set_title('not equal, looks like ellipse', fontsize=10)

axs[0, 1].plot(3 * np.cos(an), 3 * np.sin(an))
axs[0, 1].axis('equal')
axs[0, 1].set_title('equal, looks like circle', fontsize=10)

axs[1, 0].plot(3 * np.cos(an), 3 * np.sin(an))
axs[1, 0].axis('equal')
axs[1, 0].set(xlim=(-3, 3), ylim=(-4, 3))
axs[1, 0].set_title('still a circle, even after changing limits', fontsize=10)

axs[1, 1].plot(3 * np.cos(an), 3 * np.sin(an))
axs[1, 1].set_aspect('equal', 'box')
axs[1, 1].set_title('still a circle, auto-adjusted data limits', fontsize=10)

axs[2, 0].plot(3 * np.cos(an), 3 * np.sin(an))
axs[2, 0].axis('scaled')
axs[2, 0].set_title('"Scaled" makes it a circle. \n Chooses own limits', fontsize=10)

axs[2, 1].plot(3 * np.cos(an), 3 * np.sin(an))
axs[2, 1].axis('scaled')
axs[2, 1].set(xlim=(-3, 3), ylim=(-4, 7))
axs[2, 1].set_title('Scaled: a circle, with changing xy limits ', fontsize=10)


fig.tight_layout()

plt.show()

# %%
axs[1,0].get_xlim()
# Out:
# (-12.407931128941039, 12.407931128941039)

# %%
fig.get_size_inches()
# Out:
# array([6., 4.])

# %%
w,h = fig.get_size_inches()
for row in range(3):
    for col in range(2):
        print('rc:', row,col)
        ax = axs[row,col]
        l = ax.figure.subplotpars.left
        r = ax.figure.subplotpars.right
        t = ax.figure.subplotpars.top
        b = ax.figure.subplotpars.bottom
        figw = float(w)/(r-l)/2
        figh = float(h)/(t-b)
        print(figw, figh)
# Out:
# rc: 0 0
# 3.6565917594590513 4.893797790994052
# rc: 0 1
# 3.6565917594590513 4.893797790994052
# rc: 1 0
# 3.6565917594590513 4.893797790994052
# rc: 1 1
# 3.6565917594590513 4.893797790994052
# rc: 2 0
# 3.6565917594590513 4.893797790994052
# rc: 2 1
# 3.6565917594590513 4.893797790994052

# %%
fig.get_
# Out:
# <bound method Figure.get_children of <Figure size 432x288 with 6 Axes>>
